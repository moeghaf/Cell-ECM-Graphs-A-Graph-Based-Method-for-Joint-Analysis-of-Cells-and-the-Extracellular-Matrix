# %% [markdown]
# # Figure 3 – Visualization of Cell-Cell, ECM-ECM, and Cell-ECM in Cell-ECM Graphs
#
# This notebook reproduces Figure 3 from the manuscript.
#
# It includes:
# - Construction of the Cell Graph, ECM Graph, and Cell-ECM Graph
# - Node and edge visualization
# - ECM molecule expression per ECM cluster

# %% [markdown]
# ## Imports

# %%
# Standard library imports
import os
import sys
import random
from collections import Counter

# Third-party library imports
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns


# Local module imports
os.chdir('C:/Users/Adminn/Documents/GitHub/Cell_ECM_Graphs/src')
from Graph_builder import *  # Import graph-building utilities
from permutation_test import *  # Import permutation test utilities
from CellECMGraphs_multiple import *  # Import Cell-ECM graph utilities
from Helper_functions import *  # Import helper functions

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)

# Set paths for data directories
full_stack_img_dir = np.sort(glob('D:/raw/*/img/*')) # Path to IMC files 
panel_path = "C:/Users/Adminn/Downloads/panel.csv" # Path to panel - with ECM column 
cell_data_dir = np.sort(glob("C:/Users/Adminn/Desktop/PhD/cell_ECM_graphs/data/cell_data/*")) # Path to cell data files - cell types/centroids

# %%
save_folder = 'C:/Users/Adminn/Documents/GitHub/Cell_ECM_Graphs_Publication/Notebooks/figure_3/fig3_results/'

ceg = GraphBuilder(full_stack_img_path=full_stack_img_dir[0], 
                   panel_path=panel_path, 
                   feature_type = 'std+mean',
                   cell_data_path=cell_data_dir[0], 
                   save_folder=save_folder,
                   single=True,
                   save=True,
                   node_size=12)

ceg.load_imgs() # Load images
ceg.build_cell_ecm_graph() # Build the cell-ECM graph

# %%
ceg.visualize_cell_cell_interactions()

# %%
ceg.visualize_ecm_ecm_interactions()

# %%
ceg.visualize_cell_ecm_interactions()

# %%
ceg.node_size=8
ceg.visualize_cell_ecm_graph()
