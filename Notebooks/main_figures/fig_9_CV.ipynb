# %% [markdown]
# # Figure 10: 5-fold cross validation with optimized parameters

# %%
# Standard library imports
import os
import sys
import random
from collections import Counter

# Third-party library imports
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns


# Local module imports
os.chdir('C:/Users/Adminn/Documents/GitHub/CEG/src')
from Graph_builder import *  # Import graph-building utilities
from CellECMGraphs_multiple import *  # Import Cell-ECM graph utilities
from Helper_functions import *  # Import helper functions

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)

# Set paths for data directories
full_stack_img_dir = np.sort(glob('D:/raw/*/img/*')) # Path to IMC files 
panel_path = "C:/Users/Adminn/Downloads/panel.csv" # Path to panel - with ECM column 
cell_data_dir = np.sort(glob("C:/Users/Adminn/Desktop/PhD/cell_ECM_graphs/data/cell_data/*")) # Path to cell data files - cell types/centroids

# %%
# Build cell graph with optimal parameters from previous tuning

save_folder = 'C:/Users/Adminn/Documents/GitHub/Cell_ECM_Graphs_Publication/Notebooks/figure_11/fig11_results/'

# Build cell graphs 
ceg = Cell_ECM_Graphs(full_stack_img_path=full_stack_img_dir, 
                panel_path=panel_path,
                cell_data_path=cell_data_dir,
                save_folder=save_folder,
                )

# Optimal parameters for cell graph building from Bayesian optimization
Dmax_CC = 50  # Maximum distance for cell-cell connections
Dmax_CE = 0   # Maximum distance for cell-ECM connections
N_graph = 3 # Number of nearest neighbours in graph building 
K_clsf = 29 # Number of K for KNN classifier

# Build cell-ECM graphs for all regions of interest (ROIs)
ceg.build_multiple_graphs(Dmax_CC=Dmax_CC, Dmax_CE=Dmax_CE, interaction_k=N_graph)

# Cluster all ECM patches of all ROIs together 
ceg.joint_ecm_clustering()
# Out:
# Building Cell-ECM-Graphs...
# ROI 0 complete.
# ROI 1 complete.
# ROI 2 complete.
# ROI 3 complete.
# ROI 4 complete.
# ROI 5 complete.
# ROI 6 complete.
# ROI 7 complete.
# ROI 8 complete.
# ROI 9 complete.
# ROI 10 complete.
# ROI 11 complete.
# ROI 12 complete.
# ROI 13 complete.
# ROI 14 complete.
# ROI 15 complete.
# ROI 16 complete.
# ROI 17 complete.
# ROI 18 complete.
# ROI 19 complete.
# ROI 20 complete.
# ROI 21 complete.
# ROI 22 complete.
# ROI 23 complete.
# ROI 24 complete.
# ROI 25 complete.
# ROI 26 complete.
# ROI 27 complete.
# ROI 28 complete.
# ROI 29 complete.
# ROI 30 complete.
# ROI 31 complete.
# ROI 32 complete.
# ROI 33 complete.
# ROI 34 complete.
# ROI 35 complete.
# Clustering all ECM patches together ...

# %%
# Save results using optimal params for cell graph 
cg_reports_cg_params = []
cg_f1s_cg_params = []

for i in range(len(ceg.ceg_dict)):
    cell_report, cell_f1s = node_classification_knn_cv(ceg.ceg_dict[i], 'cellgraph', n_neighbors=K_clsf, n_splits=5)
    cg_f1s_cg_params.extend(cell_f1s)
# Out:
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %%
# Build cell graph with optimal parameters from previous tuning

save_folder = 'C:/Users/Adminn/Documents/GitHub/Cell_ECM_Graphs_Publication/Notebooks/figure_11/fig11_results/'

# Build cell graphs 
ceg = Cell_ECM_Graphs(full_stack_img_path=full_stack_img_dir, 
                panel_path=panel_path,
                cell_data_path=cell_data_dir,
                save_folder=save_folder,
                )

# Optimal parameters for cell-ECM graph building from Bayesian optimization
Dmax_CC = 17  # Maximum distance for cell-cell connections
Dmax_CE = 7   # Maximum distance for cell-ECM connections
N_graph = 24 # Number of nearest neighbours in graph building 
K_clsf = 15 # Number of K for KNN classifier

# Build cell-ECM graphs for all regions of interest (ROIs)
ceg.build_multiple_graphs(Dmax_CC=Dmax_CC, Dmax_CE=Dmax_CE, interaction_k=N_graph)

# Cluster all ECM patches of all ROIs together 
ceg.joint_ecm_clustering()
# Out:
# Building Cell-ECM-Graphs...
# ROI 0 complete.
# ROI 1 complete.
# ROI 2 complete.
# ROI 3 complete.
# ROI 4 complete.
# ROI 5 complete.
# ROI 6 complete.
# ROI 7 complete.
# ROI 8 complete.
# ROI 9 complete.
# ROI 10 complete.
# ROI 11 complete.
# ROI 12 complete.
# ROI 13 complete.
# ROI 14 complete.
# ROI 15 complete.
# ROI 16 complete.
# ROI 17 complete.
# ROI 18 complete.
# ROI 19 complete.
# ROI 20 complete.
# ROI 21 complete.
# ROI 22 complete.
# ROI 23 complete.
# ROI 24 complete.
# ROI 25 complete.
# ROI 26 complete.
# ROI 27 complete.
# ROI 28 complete.
# ROI 29 complete.
# ROI 30 complete.
# ROI 31 complete.
# ROI 32 complete.
# ROI 33 complete.
# ROI 34 complete.
# ROI 35 complete.
# Clustering all ECM patches together ...

# %%
# Save results using optimal params for cell ECM graph
ceg_reports_ceg_params= []
ceg_f1s_ceg_params = []


for i in range(len(ceg.ceg_dict)):
    cell_ecm_report, cell_ecm_f1s = node_classification_knn_cv(ceg.ceg_dict[i], 'cellecmgraph', n_neighbors=K_clsf, n_splits=5)
    ceg_reports_ceg_params.append(cell_ecm_report)
    ceg_f1s_ceg_params.extend(cell_ecm_f1s)
# Out:
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Adminn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

assert len(ceg_f1s_ceg_params) == 180
assert len(cg_f1s_cg_params) == 180

# Split into 5 folds × 36 ROIs
folds = 5
rois_per_fold = 36

def split_folds(f1_scores, label):
    data = []
    for i in range(folds):
        fold_scores = f1_scores[i * rois_per_fold:(i + 1) * rois_per_fold]
        data.extend([{"Fold": f"Fold {i+1}", "F1 Score": score, "Graph Type": label} for score in fold_scores])
    return data

df = pd.DataFrame(
    split_folds(ceg_f1s_ceg_params, "Cell-ECM Graph") +
    split_folds(cg_f1s_cg_params, "Cell Graph")
)

# Plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="Fold", y="F1 Score", hue="Graph Type", palette=["#f4a261", "#2a9d8f"])
sns.stripplot(data=df, x="Fold", y="F1 Score", hue="Graph Type", dodge=True, alpha=0.4, color="black", size=3)

# Tidy legend
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[:2], labels[:2], title="Graph Type")

plt.title("F1 Score Distribution per Fold", fontsize=14)
plt.ylabel("Macro F1 Score")
plt.xlabel("")
plt.grid(axis="y", linestyle="--", alpha=0.3)
plt.tight_layout()
plt.savefig("f1_score_distribution_per_fold.png", dpi=600)
# Out:
# C:\Users\Adminn\AppData\Local\Temp\ipykernel_45200\321100705.py:27: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=df, x="Fold", y="F1 Score", hue="Graph Type", dodge=True, alpha=0.4, color="black", size=3)
